# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import layers

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.fashion_mnist.load_data()
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255
for i in range(1, 10):
  plt.subplot(3, 3, i)
  plt.imshow(x_train[i], cmap=plt.get_cmap('Purples'))
  plt.show()

# %%
model = keras.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))
# Out:
# C:\Users\91883\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(x_train , y_train, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 26s 12ms/step - accuracy: 0.7627 - loss: 0.6539
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 23s 12ms/step - accuracy: 0.8827 - loss: 0.3245
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 23s 12ms/step - accuracy: 0.9011 - loss: 0.2685
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 23s 12ms/step - accuracy: 0.9146 - loss: 0.2347
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 22s 12ms/step - accuracy: 0.9229 - loss: 0.2097
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 22s 12ms/step - accuracy: 0.9305 - loss: 0.1858
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 23s 12ms/step - accuracy: 0.9377 - loss: 0.1691
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 22s 12ms/step - accuracy: 0.9407 - loss: 0.1562
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 41s 12ms/step - accuracy: 0.9461 - loss: 0.1429
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 23s 12ms/step - accuracy: 0.9544 - loss: 0.1236

# %%
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
print('\nTest accuracy:', test_acc)
# Out:
# 313/313 - 2s - 7ms/step - accuracy: 0.9109 - loss: 0.2954
#
# Test accuracy: 0.9108999967575073

# %%
preds = model.predict(x_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step

# %%
preds
# Out:
# array([[4.35369856e-08, 7.76791742e-10, 9.85516824e-09, ...,
#         3.17429544e-06, 4.66032378e-13, 9.99996543e-01],
#        [1.22408110e-07, 2.41690369e-15, 9.99983549e-01, ...,
#         1.26656163e-19, 1.62651543e-18, 2.37587607e-16],
#        [1.09440642e-11, 1.00000000e+00, 4.21561945e-16, ...,
#         6.85236768e-24, 9.70260214e-19, 1.92114353e-21],
#        ...,
#        [1.97924351e-11, 5.69686713e-14, 2.25093182e-15, ...,
#         3.44627134e-16, 1.00000000e+00, 6.86172323e-19],
#        [1.89961713e-09, 1.00000000e+00, 2.69805245e-09, ...,
#         7.54041876e-14, 4.94967132e-12, 1.92281052e-11],
#        [3.00626334e-06, 2.44456544e-07, 1.06308165e-04, ...,
#         1.24115041e-02, 9.23646148e-05, 7.92352330e-06]], dtype=float32)
